# %%
#인구 피라미드

# %%
import pandas as pd
df_m=pd.read_excel('population.xlsx',skiprows=3,index_col='행정기관',usecols='B,E:Y')#첨 3개 필요없어
df_m
# Out:
# c:\Users\dbdn1\OneDrive\Desktop\visualization\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         754,921  1,112,691  1,218,920  1,203,754  1,581,338  1,851,518
# 서울특별시      121,468    168,445    188,322    197,033    281,414    395,962
# 부산광역시       43,124     66,181     68,939     67,605     97,038    113,116
# 대구광역시       32,630     50,740     55,320     57,617     77,616     83,180
# 인천광역시       44,430     64,492     70,644     68,484     89,724    110,728
# 광주광역시       22,307     34,331     38,533     39,550     51,645     53,918
# 대전광역시       21,755     31,985     35,831     36,860     50,177     58,140
# 울산광역시       17,690     27,691     29,550     27,954     35,247     40,207
# ...

# %%
# , 가 있어서 문자로 인지해서 이걸 숫자로 바꿔야됨

df_m.iloc[0]=df_m.iloc[0].str.replace(',','').astype(int)

# %%
df_m.iloc[0]
# Out:
# 0~4세        754921
# 5~9세       1112691
# 10~14세     1218920
# 15~19세     1203754
# 20~24세     1581338
# 25~29세     1851518
# 30~34세     1703459
# 35~39세     1738641
# 40~44세     2054511
# 45~49세     2080832
# 50~54세     2291259
# 55~59세     2083442
# 60~64세     2070852
# 65~69세     1488946
# 70~74세     1020201
# 75~79세      706712
# 80~84세      482633
# 85~89세      204566
# 90~94세       51887
# 95~99세        9161
# 100세 이상       1540
# Name: 전국  , dtype: object

# %%
#여자 데이터

# %%
df_w=pd.read_excel('population.xlsx',skiprows=3,index_col='행정기관',usecols='B,AB:AV')#첨 3개 필요없어
df_w
# Out:
# c:\Users\dbdn1\OneDrive\Desktop\visualization\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국         717,188  1,059,774  1,150,635  1,123,068  1,456,860  1,658,165
# 서울특별시      113,933    160,893    178,108    189,522    314,911    420,435
# 부산광역시       41,007     62,870     65,361     63,478     92,042    103,915
# 대구광역시       30,829     48,491     52,002     52,730     68,983     72,967
# 인천광역시       41,986     61,533     66,949     64,686     83,579    100,649
# 광주광역시       21,388     32,295     36,195     36,643     47,771     49,066
# 대전광역시       20,569     30,433     33,439     34,376     47,298     50,927
# 울산광역시       16,912     26,150     27,257     24,679     27,712     30,496
# ...

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns #컬럼명을 동일시킬려고

# %%
df_w.iloc[0]=df_w.iloc[0].str.replace(',','').astype(int)

# %%
df_w.iloc[0]
# Out:
# 0~4세        717188
# 5~9세       1059774
# 10~14세     1150635
# 15~19세     1123068
# 20~24세     1456860
# 25~29세     1658165
# 30~34세     1557299
# 35~39세     1653900
# 40~44세     1985513
# 45~49세     2020818
# 50~54세     2241260
# 55~59세     2033770
# 60~64세     2112492
# 65~69세     1588492
# 70~74세     1156910
# 75~79세      911334
# 80~84세      770450
# 85~89세      450257
# 90~94세      172173
# 95~99세       39137
# 100세 이상       6899
# Name: 전국  , dtype: object

# %%
# 데이터 시각화

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size']=15
matplotlib.rcParams['axes.unicode_minus'] =False #마이너스 깨짐 현상 해결

# %%
plt.figure(figsize=(10,7))
plt.title('대한민국 인구 피라미드')
plt.barh(df_m.columns,-df_m.iloc[0]//1000)
plt.barh(df_w.columns,df_w.iloc[0]//1000)
plt.savefig('2011_인구피라미드.png',dpi=100)
plt.show()
